# %% [markdown]
# # EM Frontier - Ghana Macroeconomic Analysis

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/mathias/Documents/EM Rates Trading/africa-macro-data-1980-2022.csv')

# %%
selected_columns = ['Country', 'Year', 'Real GDP growth (annual %)', 'Inflation, consumer prices (annual %)', 'Exports of goods and services (% of GDP)','Imports of goods and services (% of GDP)', 'Gross capital formation (current US$)', 'Gross capital formation (current US$)', 'Current account balance (Net, BoP, cur. US$)', 'General government final consumption expenditure (% of GDP)', 'Household final consumption expenditure  (% of GDP)']
dataset_selected = data[selected_columns]

# %%
selected_country = 'Ghana'
country_df = dataset_selected[dataset_selected['Country'] == selected_country]
country_df = country_df.dropna()

# %%
country_df
# Out:
#      Country  Year  Real GDP growth (annual %)  \
# 990    Ghana  1981                   -3.490000
# 991    Ghana  1982                   -6.920000
# 992    Ghana  1983                   -4.570000
# 993    Ghana  1984                    8.650000
# 994    Ghana  1985                    5.080000
# 995    Ghana  1986                    5.210000
# 996    Ghana  1987                    4.790000
# 997    Ghana  1988                    5.630000
# 998    Ghana  1989                    5.090000
# 999    Ghana  1990                    3.330000
# 1000   Ghana  1991                    5.280000
# 1001   Ghana  1992                    3.880000
# 1002   Ghana  1993                    4.850000
# 1003   Ghana  1994                    3.270000
# 1004   Ghana  1995                    4.020000
# 1005   Ghana  1996                    4.600000
# 1006   Ghana  1997                    4.200000
# 1007   Ghana  1998                    4.690000
# 1008   Ghana  1999                    4.430000
# 1009   Ghana  2000                  -22.400000
# 1010   Ghana  2001                    4.180000
# 1011   Ghana  2002                    4.550000
# 1012   Ghana  2003                    5.250000
# 1013   Ghana  2004                    5.580000
# 1014   Ghana  2005                    5.870000
# 1015   Ghana  2006                    6.370000
# 1016   Ghana  2007                    4.350000
# 1017   Ghana  2008                    9.150000
# 1018   Ghana  2009                    4.840000
# 1019   Ghana  2010                    7.900000
# 1020   Ghana  2011                   14.047123
# 1021   Ghana  2012                    9.292789
# 1022   Ghana  2013                    7.312525
# 1023   Ghana  2014                    2.897439
# 1024   Ghana  2015                    2.178207
# 1025   Ghana  2016                    3.447793
# 1026   Ghana  2017                    8.143446
# 1027   Ghana  2018                    6.263481
# 1028   Ghana  2019                    6.500000
# 1029   Ghana  2020                    1.733015
# 1030   Ghana  2021                    4.015777
# 1031   Ghana  2022                    4.121155
#
#       Inflation, consumer prices (annual %)  \
# 990                              116.510000
# 991                               22.300000
# 992                              122.870000
# 993                               39.670000
# 994                               10.310000
# 995                               24.570000
# 996                               39.820000
# 997                               31.360000
# 998                               25.220000
# 999                               31.890000
# 1000                              18.030000
# 1001                              10.060000
# 1002                              24.960000
# 1003                              24.870000
# 1004                              59.460000
# 1005                              46.560000
# 1006                              27.890000
# 1007                              19.300000
# 1008                              12.400000
# 1009                              25.200000
# 1010                              32.900000
# 1011                              14.800000
# 1012                              26.700000
# 1013                              12.630000
# 1014                              15.400000
# 1015                              11.680000
# 1016                              10.730000
# 1017                              16.500000
# 1018                              19.200000
# 1019                              10.700000
# 1020                               8.700000
# 1021                               9.200000
# 1011                                          17.590000
# 1012                                          17.720000
# 1013                                          16.520000
# 1014                                          15.310000
# 1015                                           8.870000
# 1016                                           8.520000
# 1017                                           8.730000
# 1018                                           7.570000
# 1019                                           7.070000
# 1020                                          15.805912
# 1021                                          13.571400
# 1022                                          10.927904
# 1023                                          10.432040
# 1024                                           9.656949
# 1025                                           9.952314
# 1026                                           8.803559
# 1027                                           9.014342
# 1028                                           8.880743
# 1029                                           9.296457
# 1030                                           8.889962
# 1031                                           8.518535
#
#       Household final consumption expenditure  (% of GDP)
# 990                                           50.390000
# 991                                           50.160000
# 992                                           51.420000
# 993                                           47.130000
# 994                                           42.740000
# 995                                           49.600000
# 996                                           41.170000
# 997                                           37.400000
# 998                                           39.450000
# 999                                           40.260000
# 1000                                          39.520000
# 1001                                          39.840000
# 1002                                          35.690000
# 1003                                          34.060000
# 1004                                          35.040000
# 1005                                          33.920000
# 1006                                          37.990000
# 1007                                          34.680000
# 1008                                          38.180000
# 1009                                          77.610000
# 1010                                          75.120000
# 1011                                          78.730000
# 1012                                          75.270000
# 1013                                          76.170000
# 1014                                          81.260000
# 1015                                          83.710000
# 1016                                          92.390000
# 1017                                          94.230000
# 1018                                          89.000000
# 1019                                          93.610000
# 1020                                          68.715879
# 1021                                          62.516856
# 1022                                          72.658939
# 1023                                          67.637048
# 1024                                          71.962588
# 1025                                          67.791628
# 1026                                          72.006396
# 1027                                          67.584416
# 1028                                          64.106741
# 1029                                          65.325174
# 1030                                          64.464863
# 1031                                          64.975169

# %%
country = country_df['Country']
year = country_df['Year']
gdp_growth = country_df['Real GDP growth (annual %)']
inflation = country_df['Inflation, consumer prices (annual %)']
exports_gdp = country_df['Exports of goods and services (% of GDP)']
imports_gdp = country_df['Imports of goods and services (% of GDP)']
capital_formation_gdp = country_df['Gross capital formation (current US$)']
current_account_balance = country_df['Current account balance (Net, BoP, cur. US$)']
govt_consumption_gdp = country_df['General government final consumption expenditure (% of GDP)']
household_consumption_gdp = country_df['Household final consumption expenditure  (% of GDP)']

# %%
country_df.describe()
# Out:
#               Year  Real GDP growth (annual %)  \
# count    42.000000                   42.000000
# mean   2001.500000                    3.990780
# std      12.267844                    5.440191
# min    1981.000000                  -22.400000
# 25%    1991.250000                    3.913944
# 50%    2001.500000                    4.740000
# 75%    2011.750000                    5.810000
# max    2022.000000                   14.047123
#
#        Inflation, consumer prices (annual %)  \
# count                              42.000000
# mean                               24.792169
# std                                24.334880
# min                                 8.006514
# 25%                                10.964048
# 50%                                17.302302
# 75%                                26.330000
# max                               122.870000
#
#        Exports of goods and services (% of GDP)  \
# count                                 42.000000
# mean                                  22.464549
# std                                   13.509835
# min                                    1.870000
# 25%                                    9.760000
# 50%                                   25.110000
# 75%                                   33.748183
# max                                   49.020000
#
#        Imports of goods and services (% of GDP)  \
# count                                 42.000000
# mean                                  29.981870
# std                                   18.552521
# min                                    1.670000
# 25%                                   12.787500
# 50%                                   33.560809
# 75%                                   40.805000
# max                                   67.550000
#
#        Gross capital formation (current US$)  \
# count                              42.000000
# mean                             6028.480855
# std                              6901.715992
# min                               136.330000
# 25%                               888.702500
# 50%                              1947.395000
# 75%                             13234.808432
# max                             20994.317060
#
#        Gross capital formation (current US$)  \
# count                              42.000000
# mean                             6028.480855
# std                              6901.715992
# min                               136.330000
# 25%                               888.702500
# 50%                              1947.395000
# 75%                             13234.808432
# max                             20994.317060
#
#        Current account balance (Net, BoP, cur. US$)  \
# count                                     42.000000
# mean                                   -1361.672707
# std                                     1401.716797
# min                                    -5704.040000
# 25%                                    -2035.732105
# 50%                                     -653.090000
# 75%                                     -295.540000
# max                                       14.420000
#
#        General government final consumption expenditure (% of GDP)  \
# count                                          42.000000
# mean                                            8.945479
# std                                             4.141762
# min                                             3.320000
# 25%                                             6.350000
# 50%                                             8.174267
# 75%                                             9.878473
# max                                            17.840000
#
#        Household final consumption expenditure  (% of GDP)
# count                                          42.000000
# mean                                           59.654421
# std                                            19.055352
# min                                            33.920000
# 25%                                            39.945000
# 50%                                            64.285802
# 75%                                            74.504735
# max                                            94.230000

# %%
year = np.array(year)
gdp_growth = np.array(gdp_growth)
inflation = np.array(inflation)
exports_gdp = np.array(exports_gdp)

# %%
fig1, axs = plt.subplots(2,1, figsize=(15,15,))

axs[0].plot(year, gdp_growth, color='green', label='Real GDP growth (annual %)', linestyle='-', marker='o')
axs[0].set_xlabel('Time (year)')
axs[0].set_ylabel('Real GDP growth (annual %)')
axs[0].set_title('Line Plot: GDP Growth Trends for Ghana')
axs[0].grid(linestyle='--', alpha=0.6)
axs[0].legend()

axs[1].bar(year, gdp_growth, alpha=1, color='red', label='Real GDP growth (annual %)')
axs[1].set_xlabel('Year')
axs[1].set_ylabel('Real GDP growth (annual %)')
axs[1].set_title('Bar Plot: Bar Chart of GDP Growth Trends for Ghana')
axs[1].grid(linestyle='--', alpha=0.6)
axs[1].legend()

axs[1].set_xticks(year)  # Set the tick positions to be the years
axs[1].set_xticklabels(year, rotation=45) 

plt.tight_layout()  # Ensure proper spacing between subplots
plt.show()

# %% [markdown]
# ## 2011 - Year of Highest Real GDP Growth (YoY) at 14.04%

# %%
max_real_gdp_growth = country_df['Real GDP growth (annual %)'].max()
max_real_gdp_growth

country_df.loc[country_df['Real GDP growth (annual %)'] == max_real_gdp_growth]
# Out:
#      Country  Year  Real GDP growth (annual %)  \
# 1020   Ghana  2011                   14.047123
#
#       Inflation, consumer prices (annual %)  \
# 1020                                    8.7
#
#       Exports of goods and services (% of GDP)  \
# 1020                                 27.440346
#
#       Imports of goods and services (% of GDP)  \
# 1020                                  36.67662
#
#       Gross capital formation (current US$)  \
# 1020                             13258.0332
#
#       Gross capital formation (current US$)  \
# 1020                             13258.0332
#
#       Current account balance (Net, BoP, cur. US$)  \
# 1020                                      -3541.33
#
#       General government final consumption expenditure (% of GDP)  \
# 1020                                          15.805912
#
#       Household final consumption expenditure  (% of GDP)
# 1020                                          68.715879

# %% [markdown]
# ## 2000 - Year of Lowest Real GDP Growth (YoY) at -22.4%

# %%
min_real_gdp_growth = country_df['Real GDP growth (annual %)'].min()
country_df.loc[country_df['Real GDP growth (annual %)'] == min_real_gdp_growth]
# Out:
#      Country  Year  Real GDP growth (annual %)  \
# 1009   Ghana  2000                       -22.4
#
#       Inflation, consumer prices (annual %)  \
# 1009                                   25.2
#
#       Exports of goods and services (% of GDP)  \
# 1009                                     49.02
#
#       Imports of goods and services (% of GDP)  \
# 1009                                     67.55
#
#       Gross capital formation (current US$)  \
# 1009                                1812.11
#
#       Gross capital formation (current US$)  \
# 1009                                1812.11
#
#       Current account balance (Net, BoP, cur. US$)  \
# 1009                                       -482.93
#
#       General government final consumption expenditure (% of GDP)  \
# 1009                                              16.95
#
#       Household final consumption expenditure  (% of GDP)
# 1009                                              77.61

# %% [markdown]
# ## 1981 - 2022: Years of Negative Real GDP Growth

# %% [markdown]
# There has been 4 years where Ghana has experienced negative real GDP growth.

# %%
country_df.loc[country_df['Real GDP growth (annual %)'] < 0, ['Year', 'Real GDP growth (annual %)']]
# Out:
#       Year  Real GDP growth (annual %)
# 990   1981                       -3.49
# 991   1982                       -6.92
# 992   1983                       -4.57
# 1009  2000                      -22.40

# %% [markdown]
# ## Highest Real GDP Growth (top 25%)

# %% [markdown]
# Min threshold for top 25% real GDP growth

# %%
seventy_fifth_percentile = country_df['Real GDP growth (annual %)'].quantile(0.75)
seventy_fifth_percentile
# Out:
# 5.8100000000000005

# %%
country_df.loc[country_df['Real GDP growth (annual %)'] > seventy_fifth_percentile][['Year','Real GDP growth (annual %)']]
# Out:
#       Year  Real GDP growth (annual %)
# 993   1984                    8.650000
# 1014  2005                    5.870000
# 1015  2006                    6.370000
# 1017  2008                    9.150000
# 1019  2010                    7.900000
# 1020  2011                   14.047123
# 1021  2012                    9.292789
# 1022  2013                    7.312525
# 1026  2017                    8.143446
# 1027  2018                    6.263481
# 1028  2019                    6.500000

# %%
fig2, axs = plt.subplots(2,1,figsize=(15,15))

axs[0].plot(year, inflation, color='green', label='Inflation, Consumer Prices (annual %)', linestyle='-', marker='o')
axs[0].set_xlabel('Year')
axs[0].set_ylabel('Inflation, Consumer Prices (annual %)')
axs[0].set_title('Line Plot: Inflation Trends for Ghana')
axs[0].grid(linestyle='--', alpha=0.9)
axs[0].legend()

axs[1].bar(year, inflation, alpha=0.9, color='red', label='Inflation, Consumer Prices (annual %)')
axs[1].set_xlabel('Year')
axs[1].set_ylabel('Inflation, Consumer Prices (annual %)')
axs[1].set_title('Bar Plot: Bar Chart of Inflation Trends for Ghana')
axs[1].grid(linestyle='--', alpha=0.3)
axs[1].legend()

axs[1].set_xticks(year)  # Set the tick positions to be the years
axs[1].set_xticklabels(year, rotation=45)  # Set the tick labels as the years and rotate them 45 degree

plt.tight_layout()  # Ensure proper spacing between subplots
plt.show()

# %% [markdown]
# ## 1983 - Highest Inflation (YoY) at 122.87%

# %%
max_inflation = country_df['Inflation, consumer prices (annual %)'].max()
max_inflation

country_df.loc[country_df['Inflation, consumer prices (annual %)'] == max_inflation]
# Out:
#     Country  Year  Real GDP growth (annual %)  \
# 992   Ghana  1983                       -4.57
#
#      Inflation, consumer prices (annual %)  \
# 992                                 122.87
#
#      Exports of goods and services (% of GDP)  \
# 992                                      3.15
#
#      Imports of goods and services (% of GDP)  \
# 992                                      3.39
#
#      Gross capital formation (current US$)  \
# 992                                 152.15
#
#      Gross capital formation (current US$)  \
# 992                                 152.15
#
#      Current account balance (Net, BoP, cur. US$)  \
# 992                                       -160.14
#
#      General government final consumption expenditure (% of GDP)  \
# 992                                               3.32
#
#      Household final consumption expenditure  (% of GDP)
# 992                                              51.42

# %% [markdown]
# ## 2022 - Lowest Inflation (YoY) at 8.01%

# %%
min_inflation = country_df['Inflation, consumer prices (annual %)'].min()

country_df.loc[country_df['Inflation, consumer prices (annual %)'] == min_inflation]
# Out:
#      Country  Year  Real GDP growth (annual %)  \
# 1031   Ghana  2022                    4.121155
#
#       Inflation, consumer prices (annual %)  \
# 1031                               8.006514
#
#       Exports of goods and services (% of GDP)  \
# 1031                                 32.807233
#
#       Imports of goods and services (% of GDP)  \
# 1031                                 33.632418
#
#       Gross capital formation (current US$)  \
# 1031                            20994.31706
#
#       Gross capital formation (current US$)  \
# 1031                            20994.31706
#
#       Current account balance (Net, BoP, cur. US$)  \
# 1031                                  -2464.650828
#
#       General government final consumption expenditure (% of GDP)  \
# 1031                                           8.518535
#
#       Household final consumption expenditure  (% of GDP)
# 1031                                          64.975169

# %% [markdown]
# ## Ghana has never recorded a period of deflation

# %%
country_df.loc[country_df['Inflation, consumer prices (annual %)'] < 0]
# Out:
# Empty DataFrame
# Columns: [Country, Year, Real GDP growth (annual %), Inflation, consumer prices (annual %), Exports of goods and services (% of GDP), Imports of goods and services (% of GDP), Gross capital formation (current US$), Gross capital formation (current US$), Current account balance (Net, BoP, cur. US$), General government final consumption expenditure (% of GDP), Household final consumption expenditure  (% of GDP)]
# Index: []

# %%
gdp_growth
# Out:
# array([ -3.49      ,  -6.92      ,  -4.57      ,   8.65      ,
#          5.08      ,   5.21      ,   4.79      ,   5.63      ,
#          5.09      ,   3.33      ,   5.28      ,   3.88      ,
#          4.85      ,   3.27      ,   4.02      ,   4.6       ,
#          4.2       ,   4.69      ,   4.43      , -22.4       ,
#          4.18      ,   4.55      ,   5.25      ,   5.58      ,
#          5.87      ,   6.37      ,   4.35      ,   9.15      ,
#          4.84      ,   7.9       ,  14.04712346,   9.29278946,
#          7.31252508,   2.89743883,   2.1782068 ,   3.44779297,
#          8.1434465 ,   6.26348077,   6.5       ,   1.73301513,
#          4.01577745,   4.12115489])

# %%
fig, ax = plt.subplots(figsize=(15,15))

ax.scatter(gdp_growth, inflation, color='green', label='GDP Growth vs Inflation', marker='o')

ax.set_xlabel('Real GDP Growth (annual %)')
ax.set_ylabel('Inflation, consumer prices (annual %)')
ax.set_title('Regression Analysis: Real GDP Growth vs Inflation in Ghana')
ax.grid(True)
ax.legend()

regression_model = np.polyfit(gdp_growth, inflation, 1)
regression_line = np.poly1d(regression_model)

x_range = np.linspace(min(gdp_growth), max(gdp_growth)+5, 100)

ax.plot(x_range, regression_line(x_range), color='red', linestyle='--', label='Regression Line')

plt.legend()
plt.show()
