# %% [markdown]
# # EM Frontier - Kenya Macroeconomic Analysis

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/mathias/Documents/EM Rates Trading/africa-macro-data-1980-2022.csv')

# %%
selected_columns = ['Country', 'Year', 'Real GDP growth (annual %)', 'Inflation, consumer prices (annual %)', 'Exports of goods and services (% of GDP)','Imports of goods and services (% of GDP)', 'Gross capital formation (current US$)', 'Gross capital formation (current US$)', 'Current account balance (Net, BoP, cur. US$)', 'General government final consumption expenditure (% of GDP)', 'Household final consumption expenditure  (% of GDP)']
dataset_selected = data[selected_columns]

# %%
selected_country = 'Kenya'
kenya_df = dataset_selected[dataset_selected['Country'] == selected_country]
kenya_df = kenya_df.dropna()

# %%
kenya_df
# Out:
#      Country  Year  Real GDP growth (annual %)  \
# 1119   Kenya  1981                    3.760000
# 1120   Kenya  1982                    3.690000
# 1121   Kenya  1983                    1.370000
# 1122   Kenya  1984                    1.770000
# 1123   Kenya  1985                    4.270000
# 1124   Kenya  1986                    7.170000
# 1125   Kenya  1987                    5.920000
# 1126   Kenya  1988                    6.200000
# 1127   Kenya  1989                    4.700000
# 1128   Kenya  1990                    4.210000
# 1129   Kenya  1991                    1.410000
# 1130   Kenya  1992                   -0.790000
# 1131   Kenya  1993                    0.360000
# 1132   Kenya  1994                    2.630000
# 1133   Kenya  1995                    4.410000
# 1134   Kenya  1996                    4.140000
# 1135   Kenya  1997                    0.270000
# 1136   Kenya  1998                    3.360000
# 1137   Kenya  1999                    2.100000
# ...

# %%
country = kenya_df['Country']
year = kenya_df['Year']
gdp_growth = kenya_df['Real GDP growth (annual %)']
inflation = kenya_df['Inflation, consumer prices (annual %)']
exports_gdp = kenya_df['Exports of goods and services (% of GDP)']
imports_gdp = kenya_df['Imports of goods and services (% of GDP)']
capital_formation_gdp = kenya_df['Gross capital formation (current US$)']
current_account_balance = kenya_df['Current account balance (Net, BoP, cur. US$)']
govt_consumption_gdp = kenya_df['General government final consumption expenditure (% of GDP)']
household_consumption_gdp = kenya_df['Household final consumption expenditure  (% of GDP)']

# %%
kenya_df.describe()
# Out:
#               Year  Real GDP growth (annual %)  \
# count    42.000000                   42.000000
# mean   2001.500000                    4.000563
# std      12.267844                    2.255442
# min    1981.000000                   -0.790000
# 25%    1991.250000                    2.232500
# 50%    2001.500000                    4.435000
# 75%    2011.750000                    5.899056
# max    2022.000000                    8.410000
#
#        Inflation, consumer prices (annual %)  \
# count                              42.000000
# mean                               10.393658
# std                                 7.643816
# min                                 1.550000
# 25%                                 5.719375
# 50%                                 7.959167
# 75%                                11.557500
# max                                40.780000
#
#        Exports of goods and services (% of GDP)  \
# count                                 42.000000
# ...

# %%
year = np.array(year)
gdp_growth = np.array(gdp_growth)
inflation = np.array(inflation)
exports_gdp = np.array(exports_gdp)

# %%
fig1, axs = plt.subplots(2,1, figsize=(15,15,))

axs[0].plot(year, gdp_growth, color='green', label='Real GDP growth (annual %)', linestyle='-', marker='o')
axs[0].set_xlabel('Time (year)')
axs[0].set_ylabel('Real GDP growth (annual %)')
axs[0].set_title('Line Plot: GDP Growth Trends for Kenya')
axs[0].grid(linestyle='--', alpha=0.6)
axs[0].legend()

axs[1].bar(year, gdp_growth, alpha=1, color='red', label='Real GDP growth (annual %)')
axs[1].set_xlabel('Year')
axs[1].set_ylabel('Real GDP growth (annual %)')
axs[1].set_title('Bar Plot: Bar Chart of GDP Growth Trends for Kenya')
axs[1].grid(linestyle='--', alpha=0.6)
axs[1].legend()

axs[1].set_xticks(year)  # Set the tick positions to be the years
axs[1].set_xticklabels(year, rotation=45) 

plt.tight_layout()  # Ensure proper spacing between subplots
plt.show()

# %% [markdown]
# ## 2010 - Year of Highest Real GDP Growth (YoY) at 8.41%

# %%
max_real_gdp_growth = kenya_df['Real GDP growth (annual %)'].max()
max_real_gdp_growth

kenya_df.loc[kenya_df['Real GDP growth (annual %)'] == max_real_gdp_growth]
# Out:
#      Country  Year  Real GDP growth (annual %)  \
# 1148   Kenya  2010                        8.41
#
#       Inflation, consumer prices (annual %)  \
# 1148                                   4.08
#
#       Exports of goods and services (% of GDP)  \
# 1148                                     20.66
#
#       Imports of goods and services (% of GDP)  \
# 1148                                     33.57
#
#       Gross capital formation (current US$)  \
# 1148                                8336.38
#
#       Gross capital formation (current US$)  \
# 1148                                8336.38
#
#       Current account balance (Net, BoP, cur. US$)  \
# 1148                                      -2367.41
#
#       General government final consumption expenditure (% of GDP)  \
# 1148                                              14.17
#
#       Household final consumption expenditure  (% of GDP)
# 1148                                              77.15

# %% [markdown]
# ## 1992 - Year of Lowest Real GDP Growth (YoY) at -0.79%

# %%
min_real_gdp_growth = kenya_df['Real GDP growth (annual %)'].min()
kenya_df.loc[kenya_df['Real GDP growth (annual %)'] == min_real_gdp_growth]
# Out:
#      Country  Year  Real GDP growth (annual %)  \
# 1130   Kenya  1992                       -0.79
#
#       Inflation, consumer prices (annual %)  \
# 1130                                   27.3
#
#       Exports of goods and services (% of GDP)  \
# 1130                                     18.23
#
#       Imports of goods and services (% of GDP)  \
# 1130                                     18.16
#
#       Gross capital formation (current US$)  \
# 1130                                1386.67
#
#       Gross capital formation (current US$)  \
# 1130                                1386.67
#
#       Current account balance (Net, BoP, cur. US$)  \
# 1130                                       -101.19
#
#       General government final consumption expenditure (% of GDP)  \
# 1130                                              10.91
#
#       Household final consumption expenditure  (% of GDP)
# 1130                                              46.84

# %% [markdown]
# ## 1981 - 2022: Years of Negative Real GDP Growth

# %% [markdown]
# There has only been 1 year where Kenya has experienced negative real GDP growth.

# %%
kenya_df.loc[kenya_df['Real GDP growth (annual %)'] < 0, ['Year', 'Real GDP growth (annual %)']]
# Out:
#       Year  Real GDP growth (annual %)
# 1130  1992                       -0.79

# %% [markdown]
# ## Highest Real GDP Growth (top 25%)

# %% [markdown]
# Min threshold for top 25% real GDP growth

# %%
seventy_fifth_percentile = kenya_df['Real GDP growth (annual %)'].quantile(0.75)
seventy_fifth_percentile
# Out:
# 5.89905631525

# %%
kenya_df.loc[kenya_df['Real GDP growth (annual %)'] > seventy_fifth_percentile][['Year','Real GDP growth (annual %)']]
# Out:
#       Year  Real GDP growth (annual %)
# 1124  1986                    7.170000
# 1125  1987                    5.920000
# 1126  1988                    6.200000
# 1143  2005                    5.900000
# 1144  2006                    6.320000
# 1145  2007                    6.850000
# 1148  2010                    8.410000
# 1149  2011                    6.100000
# 1151  2013                    5.900000
# 1154  2016                    5.900000
# 1156  2018                    6.467686

# %%
fig2, axs = plt.subplots(2,1,figsize=(15,15))

axs[0].plot(year, inflation, color='green', label='Inflation, Consumer Prices (annual %)', linestyle='-', marker='o')
axs[0].set_xlabel('Year')
axs[0].set_ylabel('Inflation, Consumer Prices (annual %)')
axs[0].set_title('Line Plot: Inflation Trends for Kenya')
axs[0].grid(linestyle='--', alpha=0.9)
axs[0].legend()

axs[1].bar(year, inflation, alpha=0.9, color='red', label='Inflation, Consumer Prices (annual %)')
axs[1].set_xlabel('Year')
axs[1].set_ylabel('Inflation, Consumer Prices (annual %)')
axs[1].set_title('Bar Plot: Bar Chart of Inflation Trends for Kenya')
axs[1].grid(linestyle='--', alpha=0.3)
axs[1].legend()

axs[1].set_xticks(year)  # Set the tick positions to be the years
axs[1].set_xticklabels(year, rotation=45)  # Set the tick labels as the years and rotate them 45 degree

plt.tight_layout()  # Ensure proper spacing between subplots
plt.show()

# %% [markdown]
# ## 1993 - Highest Inflation (YoY) at 40.78%

# %%
max_inflation = kenya_df['Inflation, consumer prices (annual %)'].max()
max_inflation

kenya_df.loc[kenya_df['Inflation, consumer prices (annual %)'] == max_inflation]
# Out:
#      Country  Year  Real GDP growth (annual %)  \
# 1131   Kenya  1993                        0.36
#
#       Inflation, consumer prices (annual %)  \
# 1131                                  40.78
#
#       Exports of goods and services (% of GDP)  \
# 1131                                     28.39
#
#       Imports of goods and services (% of GDP)  \
# 1131                                     25.03
#
#       Gross capital formation (current US$)  \
# 1131                                1012.91
#
#       Gross capital formation (current US$)  \
# 1131                                1012.91
#
#       Current account balance (Net, BoP, cur. US$)  \
# 1131                                        170.93
#
#       General government final consumption expenditure (% of GDP)  \
# 1131                                               10.9
#
#       Household final consumption expenditure  (% of GDP)
# 1131                                              43.58

# %% [markdown]
# ## 1995 - Lowest Inflation (YoY) at 1.55%

# %%
min_inflation = kenya_df['Inflation, consumer prices (annual %)'].min()

kenya_df.loc[kenya_df['Inflation, consumer prices (annual %)'] == min_inflation]
# Out:
#      Country  Year  Real GDP growth (annual %)  \
# 1133   Kenya  1995                        4.41
#
#       Inflation, consumer prices (annual %)  \
# 1133                                   1.55
#
#       Exports of goods and services (% of GDP)  \
# 1133                                      22.1
#
#       Imports of goods and services (% of GDP)  \
# 1133                                     26.08
#
#       Gross capital formation (current US$)  \
# 1133                                1973.89
#
#       Gross capital formation (current US$)  \
# 1133                                1973.89
#
#       Current account balance (Net, BoP, cur. US$)  \
# 1133                                       -499.64
#
#       General government final consumption expenditure (% of GDP)  \
# 1133                                               10.0
#
#       Household final consumption expenditure  (% of GDP)
# 1133                                              46.66

# %% [markdown]
# ## South Africa has never recorded a period of deflation

# %%
kenya_df.loc[kenya_df['Inflation, consumer prices (annual %)'] < 0]
# Out:
# Empty DataFrame
# Columns: [Country, Year, Real GDP growth (annual %), Inflation, consumer prices (annual %), Exports of goods and services (% of GDP), Imports of goods and services (% of GDP), Gross capital formation (current US$), Gross capital formation (current US$), Current account balance (Net, BoP, cur. US$), General government final consumption expenditure (% of GDP), Household final consumption expenditure  (% of GDP)]
# Index: []

# %%
gdp_growth
# Out:
# array([ 3.76      ,  3.69      ,  1.37      ,  1.77      ,  4.27      ,
#         7.17      ,  5.92      ,  6.2       ,  4.7       ,  4.21      ,
#         1.41      , -0.79      ,  0.36      ,  2.63      ,  4.41      ,
#         4.14      ,  0.27      ,  3.36      ,  2.1       ,  0.55      ,
#         4.46      ,  0.56      ,  2.95      ,  5.1       ,  5.9       ,
#         6.32      ,  6.85      ,  0.23      ,  3.31      ,  8.41      ,
#         6.1       ,  4.5       ,  5.9       ,  5.4       ,  5.7       ,
#         5.9       ,  4.8057    ,  6.46768623,  5.4       ,  1.36978352,
#         4.99426995,  5.89622526])

# %%
fig, ax = plt.subplots(figsize=(15,15))

ax.scatter(gdp_growth, inflation, color='green', label='GDP Growth vs Inflation', marker='o')

ax.set_xlabel('Real GDP Growth (annual %)')
ax.set_ylabel('Inflation, consumer prices (annual %)')
ax.set_title('Regression Analysis: Real GDP Growth vs Inflation in South Africa')
ax.grid(True)
ax.legend()

regression_model = np.polyfit(gdp_growth, inflation, 1)
regression_line = np.poly1d(regression_model)

x_range = np.linspace(min(gdp_growth), max(gdp_growth)+5, 100)

ax.plot(x_range, regression_line(x_range), color='red', linestyle='--', label='Regression Line')

plt.legend()
plt.show()
