# %% [markdown]
# # EM Frontier - Angola Macroeconomic Analysis

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/mathias/Documents/EM Rates Trading/africa-macro-data-1980-2022.csv')

# %%
selected_columns = ['Country', 'Year', 'Real GDP growth (annual %)', 'Inflation, consumer prices (annual %)', 'Exports of goods and services (% of GDP)','Imports of goods and services (% of GDP)', 'Gross capital formation (current US$)', 'Gross capital formation (current US$)', 'Current account balance (Net, BoP, cur. US$)', 'General government final consumption expenditure (% of GDP)', 'Household final consumption expenditure  (% of GDP)']
dataset_selected = data[selected_columns]

# %%
selected_country = 'Angola'
country_df = dataset_selected[dataset_selected['Country'] == selected_country]
country_df = country_df.dropna()

# %%
country_df
# Out:
#     Country  Year  Real GDP growth (annual %)  \
# 106  Angola  2000                    0.640000
# 107  Angola  2001                    3.140000
# 108  Angola  2002                   14.830000
# 109  Angola  2003                    2.990000
# 110  Angola  2004                   10.950000
# 111  Angola  2005                   15.030000
# 112  Angola  2006                   11.550000
# 113  Angola  2007                   14.010000
# 114  Angola  2008                   11.170000
# 115  Angola  2009                    0.860000
# 116  Angola  2010                    4.860000
# 117  Angola  2011                    3.471981
# 118  Angola  2012                    8.542147
# 119  Angola  2013                    4.954590
# 120  Angola  2014                    4.822626
# 121  Angola  2015                    0.943576
# 122  Angola  2016                   -2.580097
# 123  Angola  2017                   -0.147207
# 124  Angola  2018                   -2.003577
# 125  Angola  2019                   -0.600000
# 126  Angola  2020                   -4.520618
# 127  Angola  2021                    3.140914
# 128  Angola  2022                    2.416200
#
#      Inflation, consumer prices (annual %)  \
# 106                             268.350000
# 107                             116.070000
# 108                             108.890000
# 109                              98.340000
# 110                              67.820000
# 111                              22.960000
# 112                              13.300000
# 113                              12.250000
# 114                              12.460000
# 115                              13.720000
# 116                              14.500000
# 117                              13.467015
# 118                              10.293494
# 119                               8.780441
# 120                               7.279655
# 121                              10.300000
# 122                              32.377734
# 123                              29.843587
# 124                              20.234728
# 125                              16.348885
# 126                              24.562042
# 127                              14.883728
# 128                              12.999273
#
#      Exports of goods and services (% of GDP)  \
# 106                                 57.080000
# 107                                 57.080000
# 108                                 57.080000
# 109                                 54.320000
# 110                                 58.380000
# 111                                 65.530000
# 112                                 63.470000
# 113                                 67.910000
# 114                                 72.480000
# 115                                 58.760000
# 116                                 61.540000
# 117                                 60.670000
# 118                                 55.991420
# 119                                 50.846987
# 120                                 43.976862
# 121                                 29.537411
# 122                                 28.059766
# 123                                 29.073493
# 124                                 39.082110
# 125                                 40.829401
# 126                                 36.863058
# 127                                 37.679935
# 128                                 37.875297
#
#      Imports of goods and services (% of GDP)  \
# 106                                 48.220000
# 107                                 48.220000
# 108                                 48.220000
# 109                                 49.580000
# 110                                 45.200000
# 111                                 41.060000
# 112                                 31.160000
# 113                                 40.150000
# 114                                 48.890000
# 115                                 63.690000
# 116                                 42.580000
# 117                                 39.312559
# 118                                 35.717101
# 119                                 36.104208
# 120                                 38.691569
# 121                                 32.566410
# 122                                 25.439441
# 123                                 23.077572
# 124                                 24.444542
# 125                                 25.880174
# 126                                 29.824092
# 127                                 29.326796
# 128                                 28.695951
#
#      Gross capital formation (current US$)  \
# 106                             2789.72000
# 107                             3517.23000
# 108                             4661.06000
# 109                             5424.17000
# 110                             7276.10000
# 111                            10187.92000
# 112                            12205.18000
# 113                            16793.43000
# 114                            27273.52000
# 115                            30106.14000
# 116                            23629.20000
# 117                            29539.71786
# 118                            34148.61167
# 119                            35740.02513
# 120                            40071.52122
# 121                            39741.11966
# 122                            27520.53321
# 123                            29468.85905
# 124                            21675.26972
# 125                            17691.79169
# 126                            16530.05988
# 127                            22231.87779
# 128                            25627.63050
#
#      Gross capital formation (current US$)  \
# 106                             2789.72000
# 107                             3517.23000
# 108                             4661.06000
# 109                             5424.17000
# 110                             7276.10000
# 111                            10187.92000
# 112                            12205.18000
# 113                            16793.43000
# 114                            27273.52000
# 115                            30106.14000
# 116                            23629.20000
# 117                            29539.71786
# 118                            34148.61167
# 119                            35740.02513
# 120                            40071.52122
# 121                            39741.11966
# 122                            27520.53321
# 123                            29468.85905
# 124                            21675.26972
# 125                            17691.79169
# 126                            16530.05988
# 127                            22231.87779
# 128                            25627.63050
#
#      Current account balance (Net, BoP, cur. US$)  \
# 106                                    794.520000
# 107                                  -1426.950000
# 108                                   -149.980000
# 109                                   -719.050000
# 110                                    686.180000
# 111                                   5137.310000
# 112                                  10689.820000
# 113                                  10581.260000
# 114                                   7194.240000
# 115                                  -7571.590000
# 116                                   7505.960000
# 117                                  13084.658420
# 118                                  13841.185160
# 119                                   8145.070112
# 120                                  -3747.517596
# 121                                 -10272.841900
# 122                                  -3085.195463
# 123                                   -632.867148
# 124                                   7402.606519
# 125                                   5137.394880
# 126                                  -1294.741304
# 127                                   2596.001356
# 128                                   3885.598407
#
#      General government final consumption expenditure (% of GDP)  \
# 106                                          19.130000
# 107                                          19.130000
# 108                                          19.130000
# 109                                          21.850000
# 110                                          14.310000
# 111                                          16.030000
# 112                                          15.340000
# 113                                          15.540000
# 114                                          16.810000
# 115                                          19.900000
# 116                                          17.040000
# 117                                          18.235861
# 118                                          17.799281
# 119                                          21.606606
# 120                                          18.929343
# 121                                          16.377146
# 122                                          13.917626
# 123                                          12.902258
# 124                                          10.954836
# 125                                          13.666721
# 126                                          16.408837
# 127                                          14.080701
# 128                                          13.384286
#
#      Household final consumption expenditure  (% of GDP)
# 106                                          41.510000
# 107                                          41.510000
# 108                                          41.510000
# 109                                          42.950000
# 110                                          41.610000
# 111                                          31.950000
# 112                                          29.050000
# 113                                          30.980000
# 114                                          28.800000
# 115                                          42.210000
# 116                                          35.800000
# 117                                          33.982345
# 118                                          35.323618
# 119                                          37.526197
# 120                                          46.825888
# 121                                          52.565266
# 122                                          56.174909
# 123                                          57.034127
# 124                                          53.940381
# 125                                          50.851298
# 126                                          50.088364
# 127                                          43.557564
# 128                                          40.786141

# %%
country = country_df['Country']
year = country_df['Year']
gdp_growth = country_df['Real GDP growth (annual %)']
inflation = country_df['Inflation, consumer prices (annual %)']
exports_gdp = country_df['Exports of goods and services (% of GDP)']
imports_gdp = country_df['Imports of goods and services (% of GDP)']
capital_formation_gdp = country_df['Gross capital formation (current US$)']
current_account_balance = country_df['Current account balance (Net, BoP, cur. US$)']
govt_consumption_gdp = country_df['General government final consumption expenditure (% of GDP)']
household_consumption_gdp = country_df['Household final consumption expenditure  (% of GDP)']

# %%
country_df.describe()
# Out:
#              Year  Real GDP growth (annual %)  \
# count    23.00000                   23.000000
# mean   2011.00000                    4.716110
# std       6.78233                    5.772602
# min    2000.00000                   -4.520618
# 25%    2005.50000                    0.750000
# 50%    2011.00000                    3.140914
# 75%    2016.50000                    9.746074
# max    2022.00000                   15.030000
#
#        Inflation, consumer prices (annual %)  \
# count                              23.000000
# mean                               41.305677
# std                                59.509544
# min                                 7.279655
# 25%                                12.729637
# 50%                                14.883728
# 75%                                31.110660
# max                               268.350000
#
#        Exports of goods and services (% of GDP)  \
# count                                 23.000000
# mean                                  50.613728
# std                                   13.295036
# min                                   28.059766
# 25%                                   38.478704
# 50%                                   55.991420
# 75%                                   59.715000
# max                                   72.480000
#
#        Imports of goods and services (% of GDP)  \
# count                                 23.000000
# mean                                  38.089148
# std                                   10.312543
# min                                   23.077572
# 25%                                   29.575444
# 50%                                   38.691569
# 75%                                   46.710000
# max                                   63.690000
#
#        Gross capital formation (current US$)  \
# count                              23.000000
# mean                            21036.986408
# std                             11721.901134
# min                              2789.720000
# 25%                             11196.550000
# 50%                             22231.877790
# 75%                             29504.288455
# max                             40071.521220
#
#        Gross capital formation (current US$)  \
# count                              23.000000
# mean                            21036.986408
# std                             11721.901134
# min                              2789.720000
# 25%                             11196.550000
# 50%                             22231.877790
# 75%                             29504.288455
# max                             40071.521220
#
#        Current account balance (Net, BoP, cur. US$)  \
# count                                     23.000000
# mean                                    2947.003106
# std                                     6343.598784
# min                                   -10272.841900
# 25%                                    -1006.895652
# 50%                                     2596.001356
# 75%                                     7454.283259
# max                                    13841.185160
#
#        General government final consumption expenditure (% of GDP)  \
# count                                          23.000000
# mean                                           16.629283
# std                                             2.851427
# min                                            10.954836
# 25%                                            14.195351
# 50%                                            16.408837
# 75%                                            19.029672
# max                                            21.850000
#
#        Household final consumption expenditure  (% of GDP)
# count                                          23.000000
# mean                                           42.023309
# std                                             8.489593
# min                                            28.800000
# 25%                                            35.561809
# 50%                                            41.510000
# 75%                                            48.457126
# max                                            57.034127

# %%
year = np.array(year)
gdp_growth = np.array(gdp_growth)
inflation = np.array(inflation)
exports_gdp = np.array(exports_gdp)

# %%
fig1, axs = plt.subplots(2,1, figsize=(15,15,))

axs[0].plot(year, gdp_growth, color='green', label='Real GDP growth (annual %)', linestyle='-', marker='o')
axs[0].set_xlabel('Time (year)')
axs[0].set_ylabel('Real GDP growth (annual %)')
axs[0].set_title('Line Plot: GDP Growth Trends for Angola')
axs[0].grid(linestyle='--', alpha=0.6)
axs[0].legend()

axs[1].bar(year, gdp_growth, alpha=1, color='red', label='Real GDP growth (annual %)')
axs[1].set_xlabel('Year')
axs[1].set_ylabel('Real GDP growth (annual %)')
axs[1].set_title('Bar Plot: Bar Chart of GDP Growth Trends for Angola')
axs[1].grid(linestyle='--', alpha=0.6)
axs[1].legend()

axs[1].set_xticks(year)  # Set the tick positions to be the years
axs[1].set_xticklabels(year, rotation=45) 

plt.tight_layout()  # Ensure proper spacing between subplots
plt.show()

# %% [markdown]
# ## 2005 - Year of Highest Real GDP Growth (YoY) at 15.03%

# %%
max_real_gdp_growth = country_df['Real GDP growth (annual %)'].max()
max_real_gdp_growth

country_df.loc[country_df['Real GDP growth (annual %)'] == max_real_gdp_growth]
# Out:
#     Country  Year  Real GDP growth (annual %)  \
# 111  Angola  2005                       15.03
#
#      Inflation, consumer prices (annual %)  \
# 111                                  22.96
#
#      Exports of goods and services (% of GDP)  \
# 111                                     65.53
#
#      Imports of goods and services (% of GDP)  \
# 111                                     41.06
#
#      Gross capital formation (current US$)  \
# 111                               10187.92
#
#      Gross capital formation (current US$)  \
# 111                               10187.92
#
#      Current account balance (Net, BoP, cur. US$)  \
# 111                                       5137.31
#
#      General government final consumption expenditure (% of GDP)  \
# 111                                              16.03
#
#      Household final consumption expenditure  (% of GDP)
# 111                                              31.95

# %% [markdown]
# ## 2020 - Year of Lowest Real GDP Growth (YoY) at -4.52%

# %%
min_real_gdp_growth = country_df['Real GDP growth (annual %)'].min()
country_df.loc[country_df['Real GDP growth (annual %)'] == min_real_gdp_growth]
# Out:
#     Country  Year  Real GDP growth (annual %)  \
# 126  Angola  2020                   -4.520618
#
#      Inflation, consumer prices (annual %)  \
# 126                              24.562042
#
#      Exports of goods and services (% of GDP)  \
# 126                                 36.863058
#
#      Imports of goods and services (% of GDP)  \
# 126                                 29.824092
#
#      Gross capital formation (current US$)  \
# 126                            16530.05988
#
#      Gross capital formation (current US$)  \
# 126                            16530.05988
#
#      Current account balance (Net, BoP, cur. US$)  \
# 126                                  -1294.741304
#
#      General government final consumption expenditure (% of GDP)  \
# 126                                          16.408837
#
#      Household final consumption expenditure  (% of GDP)
# 126                                          50.088364

# %% [markdown]
# ## 1981 - 2022: Years of Negative Real GDP Growth

# %% [markdown]
# There has been 5 years where Angola has experienced negative real GDP growth.

# %%
country_df.loc[country_df['Real GDP growth (annual %)'] < 0, ['Year', 'Real GDP growth (annual %)']]
# Out:
#      Year  Real GDP growth (annual %)
# 122  2016                   -2.580097
# 123  2017                   -0.147207
# 124  2018                   -2.003577
# 125  2019                   -0.600000
# 126  2020                   -4.520618

# %% [markdown]
# ## Highest Real GDP Growth (top 25%)

# %% [markdown]
# Min threshold for top 25% real GDP growth

# %%
seventy_fifth_percentile = country_df['Real GDP growth (annual %)'].quantile(0.75)
seventy_fifth_percentile
# Out:
# 9.746073667

# %%
country_df.loc[country_df['Real GDP growth (annual %)'] > seventy_fifth_percentile][['Year','Real GDP growth (annual %)']]
# Out:
#      Year  Real GDP growth (annual %)
# 108  2002                       14.83
# 110  2004                       10.95
# 111  2005                       15.03
# 112  2006                       11.55
# 113  2007                       14.01
# 114  2008                       11.17

# %%
fig2, axs = plt.subplots(2,1,figsize=(15,15))

axs[0].plot(year, inflation, color='green', label='Inflation, Consumer Prices (annual %)', linestyle='-', marker='o')
axs[0].set_xlabel('Year')
axs[0].set_ylabel('Inflation, Consumer Prices (annual %)')
axs[0].set_title('Line Plot: Inflation Trends for Angola')
axs[0].grid(linestyle='--', alpha=0.9)
axs[0].legend()

axs[1].bar(year, inflation, alpha=0.9, color='red', label='Inflation, Consumer Prices (annual %)')
axs[1].set_xlabel('Year')
axs[1].set_ylabel('Inflation, Consumer Prices (annual %)')
axs[1].set_title('Bar Plot: Bar Chart of Inflation Trends for Angola')
axs[1].grid(linestyle='--', alpha=0.3)
axs[1].legend()

axs[1].set_xticks(year)  # Set the tick positions to be the years
axs[1].set_xticklabels(year, rotation=45)  # Set the tick labels as the years and rotate them 45 degree

plt.tight_layout()  # Ensure proper spacing between subplots
plt.show()

# %% [markdown]
# ## 2000 - Highest Inflation (YoY) at 268.35%

# %%
max_inflation = country_df['Inflation, consumer prices (annual %)'].max()
max_inflation

country_df.loc[country_df['Inflation, consumer prices (annual %)'] == max_inflation]
# Out:
#     Country  Year  Real GDP growth (annual %)  \
# 106  Angola  2000                        0.64
#
#      Inflation, consumer prices (annual %)  \
# 106                                 268.35
#
#      Exports of goods and services (% of GDP)  \
# 106                                     57.08
#
#      Imports of goods and services (% of GDP)  \
# 106                                     48.22
#
#      Gross capital formation (current US$)  \
# 106                                2789.72
#
#      Gross capital formation (current US$)  \
# 106                                2789.72
#
#      Current account balance (Net, BoP, cur. US$)  \
# 106                                        794.52
#
#      General government final consumption expenditure (% of GDP)  \
# 106                                              19.13
#
#      Household final consumption expenditure  (% of GDP)
# 106                                              41.51

# %% [markdown]
# ## 2014 - Lowest Inflation (YoY) at 7.27%

# %%
min_inflation = country_df['Inflation, consumer prices (annual %)'].min()

country_df.loc[country_df['Inflation, consumer prices (annual %)'] == min_inflation]
# Out:
#     Country  Year  Real GDP growth (annual %)  \
# 120  Angola  2014                    4.822626
#
#      Inflation, consumer prices (annual %)  \
# 120                               7.279655
#
#      Exports of goods and services (% of GDP)  \
# 120                                 43.976862
#
#      Imports of goods and services (% of GDP)  \
# 120                                 38.691569
#
#      Gross capital formation (current US$)  \
# 120                            40071.52122
#
#      Gross capital formation (current US$)  \
# 120                            40071.52122
#
#      Current account balance (Net, BoP, cur. US$)  \
# 120                                  -3747.517596
#
#      General government final consumption expenditure (% of GDP)  \
# 120                                          18.929343
#
#      Household final consumption expenditure  (% of GDP)
# 120                                          46.825888

# %% [markdown]
# ## Angola has never recorded a period of deflation

# %%
country_df.loc[country_df['Inflation, consumer prices (annual %)'] < 0]
# Out:
# Empty DataFrame
# Columns: [Country, Year, Real GDP growth (annual %), Inflation, consumer prices (annual %), Exports of goods and services (% of GDP), Imports of goods and services (% of GDP), Gross capital formation (current US$), Gross capital formation (current US$), Current account balance (Net, BoP, cur. US$), General government final consumption expenditure (% of GDP), Household final consumption expenditure  (% of GDP)]
# Index: []

# %%
gdp_growth
# Out:
# array([ 0.64      ,  3.14      , 14.83      ,  2.99      , 10.95      ,
#        15.03      , 11.55      , 14.01      , 11.17      ,  0.86      ,
#         4.86      ,  3.47198138,  8.54214733,  4.95459048,  4.82262555,
#         0.94357561, -2.58009724, -0.14720742, -2.00357676, -0.6       ,
#        -4.52061841,  3.14091374,  2.41619977])

# %%
fig, ax = plt.subplots(figsize=(15,15))

ax.scatter(gdp_growth, inflation, color='green', label='GDP Growth vs Inflation', marker='o')

ax.set_xlabel('Real GDP Growth (annual %)')
ax.set_ylabel('Inflation, consumer prices (annual %)')
ax.set_title('Regression Analysis: Real GDP Growth vs Inflation in Angola')
ax.grid(True)
ax.legend()

regression_model = np.polyfit(gdp_growth, inflation, 1)
regression_line = np.poly1d(regression_model)

x_range = np.linspace(min(gdp_growth), max(gdp_growth)+5, 100)

ax.plot(x_range, regression_line(x_range), color='red', linestyle='--', label='Regression Line')

plt.legend()
plt.show()
