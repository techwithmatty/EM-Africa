# %% [markdown]
# # EM Frontier - Zambia Macroeconomic Analysis

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/mathias/Documents/EM Rates Trading/africa-macro-data-1980-2022.csv')

# %%
selected_columns = ['Country', 'Year', 'Real GDP growth (annual %)', 'Inflation, consumer prices (annual %)', 'Exports of goods and services (% of GDP)','Imports of goods and services (% of GDP)', 'Gross capital formation (current US$)', 'Gross capital formation (current US$)', 'Current account balance (Net, BoP, cur. US$)', 'General government final consumption expenditure (% of GDP)', 'Household final consumption expenditure  (% of GDP)']
dataset_selected = data[selected_columns]

# %%
selected_country = 'Zambia'
country_df = dataset_selected[dataset_selected['Country'] == selected_country]
country_df = country_df.dropna()

# %%
country_df
# Out:
#      Country  Year  Real GDP growth (annual %)  \
# 2237  Zambia  1981                   -0.820000
# 2238  Zambia  1982                    2.480000
# 2239  Zambia  1983                    2.940000
# 2240  Zambia  1984                   -0.580000
# 2241  Zambia  1985                   -0.020000
# 2242  Zambia  1986                    2.650000
# 2243  Zambia  1987                    2.750000
# 2244  Zambia  1988                    1.950000
# 2245  Zambia  1989                    0.950000
# 2246  Zambia  1990                    0.750000
# 2247  Zambia  1991                   -1.960000
# 2248  Zambia  1992                   -1.730000
# 2249  Zambia  1993                    6.800000
# 2250  Zambia  1994                   -8.630000
# 2251  Zambia  1995                    2.900000
# 2252  Zambia  1996                    6.220000
# 2253  Zambia  1997                    3.810000
# 2254  Zambia  1998                   -0.390000
# 2255  Zambia  1999                    4.650000
# 2256  Zambia  2000                    3.900000
# 2257  Zambia  2001                    5.320000
# 2258  Zambia  2002                    4.510000
# 2259  Zambia  2003                    6.950000
# 2260  Zambia  2004                    7.030000
# 2261  Zambia  2005                    7.240000
# 2262  Zambia  2006                    7.900000
# 2263  Zambia  2007                    8.350000
# 2264  Zambia  2008                    7.770000
# 2265  Zambia  2009                    9.220000
# 2266  Zambia  2010                   10.300000
# 2267  Zambia  2011                    5.564516
# 2268  Zambia  2012                    7.597520
# 2269  Zambia  2013                    5.059381
# 2270  Zambia  2014                    4.691693
# 2271  Zambia  2015                    2.924280
# 2272  Zambia  2016                    3.752209
# 2273  Zambia  2017                    3.700000
# 2274  Zambia  2018                    4.000000
# 2275  Zambia  2019                    1.400000
# 2276  Zambia  2020                   -4.902965
# 2277  Zambia  2021                    1.041294
# 2278  Zambia  2022                    1.902266
#
#       Inflation, consumer prices (annual %)  \
# 2237                              12.490000
# 2238                              11.110000
# 2239                              19.990000
# 2240                              22.210000
# 2241                              54.530000
# 2242                              55.820000
# 2243                              47.050000
# 2244                              51.000000
# 2245                             123.410000
# 2246                             107.110000
# 2247                              93.210000
# 2248                             169.050000
# 2249                             188.050000
# 2250                              53.610000
# 2251                              34.200000
# 2252                              43.090000
# 2253                              24.400000
# 2254                              24.460000
# 2255                              26.790000
# 2256                              26.100000
# 2257                              21.700000
# 2258                              22.200000
# 2259                              21.510000
# 2260                              17.570000
# 2261                              18.340000
# 2262                               9.020000
# 2263                              10.660000
# 2264                              12.450000
# 2265                              13.400000
# 2266                               8.500000
# 2267                               8.659000
# 2268                               6.600000
# 2269                               6.980000
# 2270                               7.800000
# 2271                              10.109944
# 2272                              17.869730
# 2273                               6.577312
# 2274                               7.480000
# 2275                               9.200000
# 2276                              15.362965
# 2277                              12.357326
# 2278                              10.731044
#
#       Exports of goods and services (% of GDP)  \
# 2237                                 28.580000
# 2238                                 25.060000
# 2239                                 27.380000
# 2240                                 29.860000
# 2241                                 29.610000
# 2242                                 33.320000
# 2243                                 42.410000
# 2244                                 35.780000
# 2245                                 27.070000
# 2246                                 35.380000
# 2247                                 34.610000
# 2248                                 36.390000
# 2249                                 33.570000
# 2250                                 32.950000
# 2251                                 32.900000
# 2252                                 28.480000
# 2253                                 27.370000
# 2254                                 24.620000
# 2255                                 25.040000
# 2256                                 23.920000
# 2257                                 25.110000
# 2258                                 25.220000
# 2259                                 25.100000
# 2260                                 33.030000
# 2261                                 29.780000
# 2262                                 30.970000
# 2263                                 34.650000
# 2264                                 29.480000
# 2265                                 29.210000
# 2266                                 37.030000
# 2267                                 40.471249
# 2268                                 40.082941
# 2269                                 40.482802
# 2270                                 38.822383
# 2271                                 37.138456
# 2272                                 35.324663
# 2273                                 34.956391
# 2274                                 38.095848
# 2275                                 34.635262
# 2276                                 35.255136
# 2277                                 35.750295
# 2278                                 35.868254
#
#       Imports of goods and services (% of GDP)  \
# 2237                                 41.060000
# 2238                                 33.030000
# 2239                                 26.200000
# 2240                                 28.300000
# 2241                                 30.230000
# 2242                                 34.670000
# 2243                                 38.340000
# 2244                                 28.110000
# 2245                                 34.160000
# 2246                                 36.080000
# 2247                                 37.250000
# 2248                                 47.960000
# 2249                                 40.400000
# 2250                                 33.700000
# 2251                                 36.330000
# 2252                                 35.340000
# 2253                                 30.900000
# 2254                                 31.630000
# 2255                                 34.730000
# 2256                                 36.460000
# 2257                                 39.560000
# 2258                                 36.860000
# 2259                                 36.650000
# 2260                                 34.960000
# 2261                                 31.580000
# 2262                                 28.670000
# 2263                                 34.840000
# 2264                                 32.580000
# 2265                                 29.330000
# 2266                                 27.990000
# 2267                                 32.324198
# 2268                                 35.284804
# 2269                                 39.973576
# 2270                                 37.371311
# 2271                                 42.726728
# 2272                                 38.633872
# 2273                                 36.554704
# 2274                                 37.065664
# 2275                                 34.154095
# 2276                                 32.715032
# 2277                                 31.999016
# 2278                                 32.040183
#
#       Gross capital formation (current US$)  \
# 2237                             774.280000
# 2238                             649.150000
# 2239                             456.710000
# 2240                             399.300000
# 2241                             335.390000
# 2242                             396.300000
# 2243                             288.000000
# 2244                             412.920000
# 2245                             431.720000
# 2246                             646.540000
# 2247                             372.000000
# 2248                             393.300000
# 2249                             492.420000
# 2250                             482.010000
# 2251                             553.380000
# 2252                             420.100000
# 2253                             569.820000
# 2254                             530.660000
# 2255                             507.200000
# 2256                             564.720000
# 2257                             691.100000
# 2258                             813.820000
# 2259                            1106.680000
# 2260                            1354.810000
# 2261                            1699.350000
# 2262                            3465.950000
# 2263                            3931.620000
# 2264                            5955.970000
# 2265                            4805.340000
# 2266                            6054.800000
# 2267                            7892.857951
# 2268                            8098.552935
# 2269                            9546.301122
# 2270                            9250.007169
# 2271                            9093.276812
# 2272                            8000.901744
# 2273                           10606.752970
# 2274                           10167.235020
# 2275                            9151.770935
# 2276                            9311.624694
# 2277                            9594.891786
# 2278                            9905.606804
#
#       Gross capital formation (current US$)  \
# 2237                             774.280000
# 2238                             649.150000
# 2239                             456.710000
# 2240                             399.300000
# 2241                             335.390000
# 2242                             396.300000
# 2243                             288.000000
# 2244                             412.920000
# 2245                             431.720000
# 2246                             646.540000
# 2247                             372.000000
# 2248                             393.300000
# 2249                             492.420000
# 2250                             482.010000
# 2251                             553.380000
# 2252                             420.100000
# 2253                             569.820000
# 2254                             530.660000
# 2255                             507.200000
# 2256                             564.720000
# 2257                             691.100000
# 2258                             813.820000
# 2259                            1106.680000
# 2260                            1354.810000
# 2261                            1699.350000
# 2262                            3465.950000
# 2263                            3931.620000
# 2264                            5955.970000
# 2265                            4805.340000
# 2266                            6054.800000
# 2267                            7892.857951
# 2268                            8098.552935
# 2269                            9546.301122
# 2270                            9250.007169
# 2271                            9093.276812
# 2272                            8000.901744
# 2273                           10606.752970
# 2274                           10167.235020
# 2275                            9151.770935
# 2276                            9311.624694
# 2277                            9594.891786
# 2278                            9905.606804
#
#       Current account balance (Net, BoP, cur. US$)  \
# 2237                                   -868.320000
# 2238                                   -740.420000
# 2239                                   -329.020000
# 2240                                   -332.020000
# 2241                                   -349.600000
# 2242                                   -286.200000
# 2243                                   -103.600000
# 2244                                     15.570000
# 2245                                   -150.470000
# 2246                                    -92.620000
# 2247                                      9.310000
# 2248                                   -117.980000
# 2249                                    -87.640000
# 2250                                     47.580000
# 2251                                   -144.850000
# 2252                                   -121.520000
# 2253                                   -238.760000
# 2254                                   -540.190000
# 2255                                   -428.560000
# 2256                                   -596.520000
# 2257                                   -698.570000
# 2258                                   -490.980000
# 2259                                   -614.030000
# 2260                                   -565.020000
# 2261                                   -599.030000
# 2262                                    124.400000
# 2263                                   -754.490000
# 2264                                   -767.550000
# 2265                                    912.630000
# 2266                                   1525.290000
# 2267                                    955.581372
# 2268                                   1138.534669
# 2269                                   -232.014781
# 2270                                    581.230461
# 2271                                   -570.778959
# 2272                                   -684.370974
# 2273                                   -435.005245
# 2274                                   -341.779994
# 2275                                    144.712285
# 2276                                   -103.710037
# 2277                                      8.234086
# 2278                                    -42.460950
#
#       General government final consumption expenditure (% of GDP)  \
# 2237                                          28.230000
# 2238                                          25.080000
# 2239                                          20.070000
# 2240                                          21.410000
# 2241                                          19.380000
# 2242                                          21.230000
# 2243                                          21.920000
# 2244                                          15.970000
# 2245                                          13.860000
# 2246                                          18.760000
# 2247                                          31.820000
# 2248                                          15.010000
# 2249                                          18.430000
# 2250                                          11.990000
# 2251                                          14.110000
# 2252                                          16.610000
# 2253                                          15.870000
# 2254                                          14.440000
# 2255                                          11.880000
# 2256                                           8.570000
# 2257                                           9.030000
# 2258                                          10.490000
# 2259                                          12.340000
# 2260                                          15.050000
# 2261                                          15.920000
# 2262                                           9.520000
# 2263                                           7.980000
# 2264                                          10.360000
# 2265                                           9.980000
# 2266                                           9.380000
# 2267                                          10.245797
# 2268                                          11.897400
# 2269                                          12.184319
# 2270                                          14.523908
# 2271                                          14.780602
# 2272                                          16.071869
# 2273                                          13.706543
# 2274                                          12.755016
# 2275                                          17.683774
# 2276                                          17.081702
# 2277                                          16.109206
# 2278                                          15.699769
#
#       Household final consumption expenditure  (% of GDP)
# 2237                                          64.780000
# 2238                                          58.250000
# 2239                                          50.490000
# 2240                                          49.660000
# 2241                                          50.390000
# 2242                                          40.350000
# 2243                                          67.790000
# 2244                                          71.900000
# 2245                                          83.300000
# 2246                                          63.500000
# 2247                                          59.800000
# 2248                                          84.670000
# 2249                                          73.360000
# 2250                                          67.090000
# 2251                                          66.130000
# 2252                                          69.490000
# 2253                                          65.280000
# 2254                                          69.080000
# 2255                                          74.900000
# 2256                                          88.280000
# 2257                                          88.540000
# 2258                                          81.740000
# 2259                                          76.630000
# 2260                                          65.100000
# 2261                                          65.480000
# 2262                                          61.010000
# 2263                                          64.240000
# 2264                                          59.490000
# 2265                                          58.790000
# 2266                                          50.380000
# 2267                                          47.962812
# 2268                                          51.549531
# 2269                                          53.267937
# 2270                                          49.955743
# 2271                                          48.002595
# 2272                                          49.031121
# 2273                                          46.931565
# 2274                                          47.432785
# 2275                                          42.574507
# 2276                                          37.994231
# 2277                                          36.767828
# 2278                                          37.271376

# %%
country = country_df['Country']
year = country_df['Year']
gdp_growth = country_df['Real GDP growth (annual %)']
inflation = country_df['Inflation, consumer prices (annual %)']
exports_gdp = country_df['Exports of goods and services (% of GDP)']
imports_gdp = country_df['Imports of goods and services (% of GDP)']
capital_formation_gdp = country_df['Gross capital formation (current US$)']
current_account_balance = country_df['Current account balance (Net, BoP, cur. US$)']
govt_consumption_gdp = country_df['General government final consumption expenditure (% of GDP)']
household_consumption_gdp = country_df['Household final consumption expenditure  (% of GDP)']

# %%
country_df.describe()
# Out:
#               Year  Real GDP growth (annual %)  \
# count    42.000000                   42.000000
# mean   2001.500000                    3.331909
# std      12.267844                    3.816662
# min    1981.000000                   -8.630000
# 25%    1991.250000                    1.130971
# 50%    2001.500000                    3.726104
# 75%    2011.750000                    6.056129
# max    2022.000000                   10.300000
#
#        Inflation, consumer prices (annual %)  \
# count                              42.000000
# mean                               34.827555
# std                                42.186338
# min                                 6.577312
# 25%                                10.677761
# 50%                                19.165000
# 75%                                40.867500
# max                               188.050000
#
#        Exports of goods and services (% of GDP)  \
# count                                 42.000000
# mean                                  32.399135
# std                                    5.078163
# min                                   23.920000
# 25%                                   28.505000
# 50%                                   33.175000
# 75%                                   35.772574
# max                                   42.410000
#
#        Imports of goods and services (% of GDP)  \
# count                                 42.000000
# mean                                  34.731981
# std                                    4.379046
# min                                   26.200000
# 25%                                   32.009308
# 50%                                   34.785000
# 75%                                   37.014248
# max                                   47.960000
#
#        Gross capital formation (current US$)  \
# count                              42.000000
# mean                             3575.598570
# std                              3906.116971
# min                               288.000000
# 25%                               484.612500
# 50%                               794.050000
# 75%                              7973.890796
# max                             10606.752970
#
#        Gross capital formation (current US$)  \
# count                              42.000000
# mean                             3575.598570
# std                              3906.116971
# min                               288.000000
# 25%                               484.612500
# 50%                               794.050000
# 75%                              7973.890796
# max                             10606.752970
#
#        Current account balance (Net, BoP, cur. US$)  \
# count                                     42.000000
# mean                                    -165.833525
# std                                      527.586840
# min                                     -868.320000
# 25%                                     -558.812500
# 50%                                     -235.387391
# 75%                                       -4.439673
# max                                     1525.290000
#
#        General government final consumption expenditure (% of GDP)  \
# count                                          42.000000
# mean                                           15.414998
# std                                             5.181610
# min                                             7.980000
# 25%                                            11.920550
# 50%                                            14.895301
# 75%                                            17.533256
# max                                            31.820000
#
#        Household final consumption expenditure  (% of GDP)
# count                                          42.000000
# mean                                           60.443620
# std                                            14.038953
# min                                            36.767828
# 25%                                            49.733936
# 50%                                            60.405000
# 75%                                            68.757500
# max                                            88.540000

# %%
year = np.array(year)
gdp_growth = np.array(gdp_growth)
inflation = np.array(inflation)
exports_gdp = np.array(exports_gdp)

# %%
fig1, axs = plt.subplots(2,1, figsize=(15,15,))

axs[0].plot(year, gdp_growth, color='green', label='Real GDP growth (annual %)', linestyle='-', marker='o')
axs[0].set_xlabel('Time (year)')
axs[0].set_ylabel('Real GDP growth (annual %)')
axs[0].set_title('Line Plot: GDP Growth Trends for Zambia')
axs[0].grid(linestyle='--', alpha=0.6)
axs[0].legend()

axs[1].bar(year, gdp_growth, alpha=1, color='red', label='Real GDP growth (annual %)')
axs[1].set_xlabel('Year')
axs[1].set_ylabel('Real GDP growth (annual %)')
axs[1].set_title('Bar Plot: Bar Chart of GDP Growth Trends for Zambia')
axs[1].grid(linestyle='--', alpha=0.6)
axs[1].legend()

axs[1].set_xticks(year)  # Set the tick positions to be the years
axs[1].set_xticklabels(year, rotation=45) 

plt.tight_layout()  # Ensure proper spacing between subplots
plt.show()

# %% [markdown]
# ## 2010 - Year of Highest Real GDP Growth (YoY) at 10.03%

# %%
max_real_gdp_growth = country_df['Real GDP growth (annual %)'].max()
max_real_gdp_growth

country_df.loc[country_df['Real GDP growth (annual %)'] == max_real_gdp_growth]
# Out:
#      Country  Year  Real GDP growth (annual %)  \
# 2266  Zambia  2010                        10.3
#
#       Inflation, consumer prices (annual %)  \
# 2266                                    8.5
#
#       Exports of goods and services (% of GDP)  \
# 2266                                     37.03
#
#       Imports of goods and services (% of GDP)  \
# 2266                                     27.99
#
#       Gross capital formation (current US$)  \
# 2266                                 6054.8
#
#       Gross capital formation (current US$)  \
# 2266                                 6054.8
#
#       Current account balance (Net, BoP, cur. US$)  \
# 2266                                       1525.29
#
#       General government final consumption expenditure (% of GDP)  \
# 2266                                               9.38
#
#       Household final consumption expenditure  (% of GDP)
# 2266                                              50.38

# %% [markdown]
# ## 1994 - Year of Lowest Real GDP Growth (YoY) at -8.63%

# %%
min_real_gdp_growth = country_df['Real GDP growth (annual %)'].min()
country_df.loc[country_df['Real GDP growth (annual %)'] == min_real_gdp_growth]
# Out:
#      Country  Year  Real GDP growth (annual %)  \
# 2250  Zambia  1994                       -8.63
#
#       Inflation, consumer prices (annual %)  \
# 2250                                  53.61
#
#       Exports of goods and services (% of GDP)  \
# 2250                                     32.95
#
#       Imports of goods and services (% of GDP)  \
# 2250                                      33.7
#
#       Gross capital formation (current US$)  \
# 2250                                 482.01
#
#       Gross capital formation (current US$)  \
# 2250                                 482.01
#
#       Current account balance (Net, BoP, cur. US$)  \
# 2250                                         47.58
#
#       General government final consumption expenditure (% of GDP)  \
# 2250                                              11.99
#
#       Household final consumption expenditure  (% of GDP)
# 2250                                              67.09

# %% [markdown]
# ## 1981 - 2022: Years of Negative Real GDP Growth

# %% [markdown]
# There has been 8 years where Zambia has experienced negative real GDP growth.

# %%
country_df.loc[country_df['Real GDP growth (annual %)'] < 0, ['Year', 'Real GDP growth (annual %)']]
# Out:
#       Year  Real GDP growth (annual %)
# 2237  1981                   -0.820000
# 2240  1984                   -0.580000
# 2241  1985                   -0.020000
# 2247  1991                   -1.960000
# 2248  1992                   -1.730000
# 2250  1994                   -8.630000
# 2254  1998                   -0.390000
# 2276  2020                   -4.902965

# %% [markdown]
# ## Highest Real GDP Growth (top 25%)

# %% [markdown]
# Min threshold for top 25% real GDP growth

# %%
seventy_fifth_percentile = country_df['Real GDP growth (annual %)'].quantile(0.75)
seventy_fifth_percentile
# Out:
# 6.05612903225

# %%
country_df.loc[country_df['Real GDP growth (annual %)'] > seventy_fifth_percentile][['Year','Real GDP growth (annual %)']]
# Out:
#       Year  Real GDP growth (annual %)
# 2249  1993                     6.80000
# 2252  1996                     6.22000
# 2259  2003                     6.95000
# 2260  2004                     7.03000
# 2261  2005                     7.24000
# 2262  2006                     7.90000
# 2263  2007                     8.35000
# 2264  2008                     7.77000
# 2265  2009                     9.22000
# 2266  2010                    10.30000
# 2268  2012                     7.59752

# %%
fig2, axs = plt.subplots(2,1,figsize=(15,15))

axs[0].plot(year, inflation, color='green', label='Inflation, Consumer Prices (annual %)', linestyle='-', marker='o')
axs[0].set_xlabel('Year')
axs[0].set_ylabel('Inflation, Consumer Prices (annual %)')
axs[0].set_title('Line Plot: Inflation Trends for Zambia')
axs[0].grid(linestyle='--', alpha=0.9)
axs[0].legend()

axs[1].bar(year, inflation, alpha=0.9, color='red', label='Inflation, Consumer Prices (annual %)')
axs[1].set_xlabel('Year')
axs[1].set_ylabel('Inflation, Consumer Prices (annual %)')
axs[1].set_title('Bar Plot: Bar Chart of Inflation Trends for Zambia')
axs[1].grid(linestyle='--', alpha=0.3)
axs[1].legend()

axs[1].set_xticks(year)  # Set the tick positions to be the years
axs[1].set_xticklabels(year, rotation=45)  # Set the tick labels as the years and rotate them 45 degree

plt.tight_layout()  # Ensure proper spacing between subplots
plt.show()

# %% [markdown]
# ## 1993 - Highest Inflation (YoY) at 188.87%

# %%
max_inflation = country_df['Inflation, consumer prices (annual %)'].max()
max_inflation

country_df.loc[country_df['Inflation, consumer prices (annual %)'] == max_inflation]
# Out:
#      Country  Year  Real GDP growth (annual %)  \
# 2249  Zambia  1993                         6.8
#
#       Inflation, consumer prices (annual %)  \
# 2249                                 188.05
#
#       Exports of goods and services (% of GDP)  \
# 2249                                     33.57
#
#       Imports of goods and services (% of GDP)  \
# 2249                                      40.4
#
#       Gross capital formation (current US$)  \
# 2249                                 492.42
#
#       Gross capital formation (current US$)  \
# 2249                                 492.42
#
#       Current account balance (Net, BoP, cur. US$)  \
# 2249                                        -87.64
#
#       General government final consumption expenditure (% of GDP)  \
# 2249                                              18.43
#
#       Household final consumption expenditure  (% of GDP)
# 2249                                              73.36

# %% [markdown]
# ## 2017 - Lowest Inflation (YoY) at 6.57%

# %%
min_inflation = country_df['Inflation, consumer prices (annual %)'].min()

country_df.loc[country_df['Inflation, consumer prices (annual %)'] == min_inflation]
# Out:
#      Country  Year  Real GDP growth (annual %)  \
# 2273  Zambia  2017                         3.7
#
#       Inflation, consumer prices (annual %)  \
# 2273                               6.577312
#
#       Exports of goods and services (% of GDP)  \
# 2273                                 34.956391
#
#       Imports of goods and services (% of GDP)  \
# 2273                                 36.554704
#
#       Gross capital formation (current US$)  \
# 2273                            10606.75297
#
#       Gross capital formation (current US$)  \
# 2273                            10606.75297
#
#       Current account balance (Net, BoP, cur. US$)  \
# 2273                                   -435.005245
#
#       General government final consumption expenditure (% of GDP)  \
# 2273                                          13.706543
#
#       Household final consumption expenditure  (% of GDP)
# 2273                                          46.931565

# %% [markdown]
# ## Zambia has never recorded a period of deflation

# %%
country_df.loc[country_df['Inflation, consumer prices (annual %)'] < 0]
# Out:
# Empty DataFrame
# Columns: [Country, Year, Real GDP growth (annual %), Inflation, consumer prices (annual %), Exports of goods and services (% of GDP), Imports of goods and services (% of GDP), Gross capital formation (current US$), Gross capital formation (current US$), Current account balance (Net, BoP, cur. US$), General government final consumption expenditure (% of GDP), Household final consumption expenditure  (% of GDP)]
# Index: []

# %%
gdp_growth
# Out:
# array([-0.82      ,  2.48      ,  2.94      , -0.58      , -0.02      ,
#         2.65      ,  2.75      ,  1.95      ,  0.95      ,  0.75      ,
#        -1.96      , -1.73      ,  6.8       , -8.63      ,  2.9       ,
#         6.22      ,  3.81      , -0.39      ,  4.65      ,  3.9       ,
#         5.32      ,  4.51      ,  6.95      ,  7.03      ,  7.24      ,
#         7.9       ,  8.35      ,  7.77      ,  9.22      , 10.3       ,
#         5.56451613,  7.59751953,  5.05938096,  4.69169282,  2.92428044,
#         3.75220894,  3.7       ,  4.        ,  1.4       , -4.9029652 ,
#         1.04129416,  1.90226586])

# %%
fig, ax = plt.subplots(figsize=(15,15))

ax.scatter(gdp_growth, inflation, color='green', label='GDP Growth vs Inflation', marker='o')

ax.set_xlabel('Real GDP Growth (annual %)')
ax.set_ylabel('Inflation, consumer prices (annual %)')
ax.set_title('Regression Analysis: Real GDP Growth vs Inflation in Zambia')
ax.grid(True)
ax.legend()

regression_model = np.polyfit(gdp_growth, inflation, 1)
regression_line = np.poly1d(regression_model)

x_range = np.linspace(min(gdp_growth), max(gdp_growth)+5, 100)

ax.plot(x_range, regression_line(x_range), color='red', linestyle='--', label='Regression Line')

plt.legend()
plt.show()
